# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitha010-1/2025-2026-EVEN--AI-DS-HARSHITHA-4082/blob/main/17.02.2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = [10, 12, 15, 18, 20, 22, 25, 30, 35, 40]
df = pd.DataFrame(data, columns=["values"])
print("Dataset:")
print(df)
print("\nSummary statistics:")
print(df.describe())
print("\nVariance:", np.var(data))
print("Standard deviation:", np.std(data))
plt.hist(data, bins=5, edgecolor='black')
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Data Distribution")
plt.show()
mean_value = np.mean(data)
median_value = np.median(data)
print("\nInference:")
print("Mean value:", mean_value)
print("Median value:", median_value)

if mean_value > median_value:
    print("Data is slightly right-skewed")
elif mean_value < median_value:
    print("Data is slightly left-skewed")
else:
    print("Data is symmetric")
# Out:
# Dataset:
#    values
# 0      10
# 1      12
# 2      15
# 3      18
# 4      20
# 5      22
# 6      25
# 7      30
# 8      35
# 9      40
#
# Summary statistics:
#           values
# count  10.000000
# mean   22.700000
# std     9.855061
# min    10.000000
# 25%    15.750000
# 50%    21.000000
# 75%    28.750000
# max    40.000000
#
# Variance: 87.41
# Standard deviation: 9.34933152690608
# Inference:
# Mean value: 22.7
# Median value: 21.0
# Data is slightly right-skewed

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
url = "https://raw.githubusercontent.com/dataprofessor/data/master/BostonHousing.csv"
df = pd.read_csv(url)
print("Dataset (first 10 rows):")
print(df.head(10))
data = df["medv"]
print("In summary statistics:")
print(data.describe())
print("In Variance:", np.var(data))
print("Standard deviation:", np.std(data))
plt.hist(data, bins=10, color='skyblue', edgecolor='black')
plt.axvline(np.mean(data), color='red',
            linestyle='dashed',
            linewidth=2,
            label=f"Mean: {np.mean(data):.2f}")
plt.axvline(np.median(data), color='green',
            linestyle='dashed',
            linewidth=2,
            label=f"Median: {np.median(data):.2f}")
plt.xlabel("Median Home Value (medv)")
plt.ylabel("frequency")
plt.title("Distribution of Median Home Value")
plt.legend()
plt.show()
mean_value = np.mean(data)
median_value = np.median(data)
print("In Inter_Inference:")
print("Mean value:", mean_value)
print("Median value:", median_value)
if mean_value > median_value:
    print("Data is slightly right_skewed")
elif mean_value < median_value:
    print("Data is slightly left-skewed")
else:
    print("Data is symmetric")
# Out:
# Dataset (first 10 rows):
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# ...
