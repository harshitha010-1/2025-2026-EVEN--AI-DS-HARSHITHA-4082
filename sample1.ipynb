# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitha010-1/2025-2026-EVEN--AI-DS-HARSHITHA-4082/blob/main/sample1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = {1, 2, 3}
s.add(4)

# Dictionary
d = {"a": 1, "b": 2}
d["c"] = 3

print(s)
print(d)
